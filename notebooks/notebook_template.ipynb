# %% [markdown]
# # [Notebook Title]
# **Series:** Tribal Fire Science & Indigenous Data Sovereignty
# **Author:** [Author]
# **Last Updated:** [YYYY-MM-DD]
# **Data Sources:** [List primary sources]
#
# ## Overview
# [1–3 sentence description of what this notebook analyzes and why it matters.]
#
# ## Research Questions
# - [Research question 1]
# - [Research question 2]
#
# ## Data Sovereignty Note
# > See the acknowledgment printed below. This notebook uses real data from
# > documented public sources. No synthetic data is used.

# %%
# Standard imports
import sys
from pathlib import Path

# Make/src importable regardless of notebook location
REPO_ROOT = Path().resolve().parents[0]  # adjust depth if notebooks/ is nested
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# Project modules
from src.data import constants, loaders, validators
from src.viz import maps, charts, styles
from src.geo import utils as geo_utils
from src.indigenous.sovereignty import print_data_acknowledgment, SOURCES

styles.apply_mpl_style()
# %matplotlib inline

# %%
# Data sovereignty acknowledgment
# List the source keys relevant to THIS notebook
print_data_acknowledgment(source_keys=["bia_tribal_boundaries", "nifc_perimeters"])

# %% [markdown]
# ## Load Data

# %%
# Load datasets 
# Use loaders from src/data/loaders.py
# Pass force_refresh=True to re-download; omit to use cache.

# Example:
# tribal = loaders.load_bia_tribal_boundaries()
# tribal = validators.validate_geodataframe(tribal, "bia_tribal_boundaries")
# tribal.shape

# %% [markdown]
# ## Process / Filter

# %%
# Processing steps go here

# %% [markdown]
# ## Analyze

# %%
# Analysis code here

# %% [markdown]
# ## Visualize

# %%
# Map example:
# m = maps.base_map()
# m = maps.add_tribal_boundaries(m, tribal, tooltip_field="NAMELSAD")
# m

# %% [markdown]
# ## Summary and Findings
#
# [Narrative summary of findings. What does this mean for Tribal fire management? Can include relevant questions]

# %% [markdown]
# ---
# ## References
#
# [Auto-generate with `from src.indigenous.sovereignty import generate_citations`]
